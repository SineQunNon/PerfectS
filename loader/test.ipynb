# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# !pwd
# !echo $PYTHONPATH
# Out:
# /Users/sinequanon/Documents/PerfectS/loader

# %%
import sys
sys.path.append("/Users/sinequanon/Documents/PerfectS")

from llm.get_ppt_input import get_ppt_input

answer = get_ppt_input("/Users/sinequanon/Documents/PerfectS/data/pdf_data/TEST_01.pdf")

print(answer)
print(type(answer))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[8], line 6
#       2 sys.path.append("/Users/sinequanon/Documents/PerfectS")
#       4 from llm.get_ppt_input import get_ppt_input
# ----> 6 answer = get_ppt_input("/Users/sinequanon/Documents/PerfectS/data/pdf_data/TEST_01.pdf")
#       8 print(answer)
#       9 print(type(answer))
#
# File ~/Documents/PerfectS/llm/get_ppt_input.py:28, in get_ppt_input(pdf_path)
#      24 #------------------------chain--------------------------#
#      26 chain = {'input' : RunnablePassthrough()} | prompt | llm | parser
# ---> 28 answer = chain.invoke(llm_input)
#      30 return answer
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/langchain_core/runnables/base.py:2873, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2871             input = step.invoke(input, config, **kwargs)
#    2872         else:
# -> 2873             input = step.invoke(input, config)
#    2874 # finish the root run
#    2875 except BaseException as e:
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:265, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     254 def invoke(
#     255     self,
#     256     input: LanguageModelInput,
#    (...)
#     260     **kwargs: Any,
#     261 ) -> BaseMessage:
#     262     config = ensure_config(config)
#     263     return cast(
#     264         ChatGeneration,
# --> 265         self.generate_prompt(
#     266             [self._convert_input(input)],
#     267             stop=stop,
#     268             callbacks=config.get("callbacks"),
#     269             tags=config.get("tags"),
#     270             metadata=config.get("metadata"),
#     271             run_name=config.get("run_name"),
#     272             run_id=config.pop("run_id", None),
#     273             **kwargs,
#     274         ).generations[0][0],
#     275     ).message
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:698, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     690 def generate_prompt(
#     691     self,
#     692     prompts: List[PromptValue],
#    (...)
#     695     **kwargs: Any,
#     696 ) -> LLMResult:
#     697     prompt_messages = [p.to_messages() for p in prompts]
# --> 698     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:555, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     553         if run_managers:
#     554             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 555         raise e
#     556 flattened_outputs = [
#     557     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     558     for res in results
#     559 ]
#     560 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:545, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     542 for i, m in enumerate(messages):
#     543     try:
#     544         results.append(
# --> 545             self._generate_with_cache(
#     546                 m,
#     547                 stop=stop,
#     548                 run_manager=run_managers[i] if run_managers else None,
#     549                 **kwargs,
#     550             )
#     551         )
#     552     except BaseException as e:
#     553         if run_managers:
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:770, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     768 else:
#     769     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 770         result = self._generate(
#     771             messages, stop=stop, run_manager=run_manager, **kwargs
#     772         )
#     773     else:
#     774         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:589, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     587     generation_info = {"headers": dict(raw_response.headers)}
#     588 else:
# --> 589     response = self.client.create(**payload)
#     590     generation_info = None
#     591 return self._create_chat_result(response, generation_info)
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/openai/resources/chat/completions.py:606, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     573 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     574 def create(
#     575     self,
#    (...)
#     604     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     605 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 606     return self._post(
#     607         "/chat/completions",
#     608         body=maybe_transform(
#     609             {
#     610                 "messages": messages,
#     611                 "model": model,
#     612                 "frequency_penalty": frequency_penalty,
#     613                 "function_call": function_call,
#     614                 "functions": functions,
#     615                 "logit_bias": logit_bias,
#     616                 "logprobs": logprobs,
#     617                 "max_tokens": max_tokens,
#     618                 "n": n,
#     619                 "parallel_tool_calls": parallel_tool_calls,
#     620                 "presence_penalty": presence_penalty,
#     621                 "response_format": response_format,
#     622                 "seed": seed,
#     623                 "stop": stop,
#     624                 "stream": stream,
#     625                 "stream_options": stream_options,
#     626                 "temperature": temperature,
#     627                 "tool_choice": tool_choice,
#     628                 "tools": tools,
#     629                 "top_logprobs": top_logprobs,
#     630                 "top_p": top_p,
#     631                 "user": user,
#     632             },
#     633             completion_create_params.CompletionCreateParams,
#     634         ),
#     635         options=make_request_options(
#     636             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     637         ),
#     638         cast_to=ChatCompletion,
#     639         stream=stream or False,
#     640         stream_cls=Stream[ChatCompletionChunk],
#     641     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/openai/_base_client.py:942, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     939 self._prepare_options(options)
#     941 retries = self._remaining_retries(remaining_retries, options)
# --> 942 request = self._build_request(options)
#     943 self._prepare_request(request)
#     945 kwargs: HttpxSendArgs = {}
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/openai/_base_client.py:459, in BaseClient._build_request(self, options)
#     456     else:
#     457         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 459 headers = self._build_headers(options)
#     460 params = _merge_mappings(self._custom_query, options.params)
#     461 content_type = headers.get("Content-Type")
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/openai/_base_client.py:417, in BaseClient._build_headers(self, options)
#     414 self._validate_headers(headers_dict, custom_headers)
#     416 # headers are case-insensitive while dictionaries are not.
# --> 417 headers = httpx.Headers(headers_dict)
#     419 idempotency_header = self._idempotency_header
#     420 if idempotency_header and options.method.lower() != "get" and idempotency_header not in headers:
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/httpx/_models.py:72, in Headers.__init__(self, headers, encoding)
#      70     self._list = list(headers._list)
#      71 elif isinstance(headers, Mapping):
# ---> 72     self._list = [
#      73         (
#      74             normalize_header_key(k, lower=False, encoding=encoding),
#      75             normalize_header_key(k, lower=True, encoding=encoding),
#      76             normalize_header_value(v, encoding),
#      77         )
#      78         for k, v in headers.items()
#      79     ]
#      80 else:
#      81     self._list = [
#      82         (
#      83             normalize_header_key(k, lower=False, encoding=encoding),
#    (...)
#      87         for k, v in headers
#      88     ]
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/httpx/_models.py:76, in <listcomp>(.0)
#      70     self._list = list(headers._list)
#      71 elif isinstance(headers, Mapping):
#      72     self._list = [
#      73         (
#      74             normalize_header_key(k, lower=False, encoding=encoding),
#      75             normalize_header_key(k, lower=True, encoding=encoding),
# ---> 76             normalize_header_value(v, encoding),
#      77         )
#      78         for k, v in headers.items()
#      79     ]
#      80 else:
#      81     self._list = [
#      82         (
#      83             normalize_header_key(k, lower=False, encoding=encoding),
#    (...)
#      87         for k, v in headers
#      88     ]
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/httpx/_utils.py:53, in normalize_header_value(value, encoding)
#      51 if isinstance(value, bytes):
#      52     return value
# ---> 53 return value.encode(encoding or "ascii")
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 66-69: ordinal not in range(128)

# %%
import os

print(f"[API KEY]\n{os.environ['OPENAI_API_KEY'][:-15]}" + "*" * 15)

from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("Capstone")
# Out:
# [API KEY]
# sk-proj-U0WLy34YRK12aOm7ae0nT3BlbkFJ084LfANMI2It***************
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# Capstone

# %%
from pdf_loader import load_pdf
from animal_info import get_animal_data
from subjective import extract_date_position, extract_data_via_interval_info, extract_subjective_data
from assessment import assessment_exists, plan_exists_for_assessment, extract_assessment_data, make_assessment_table
from plan import plan_exists, extract_plan_data, make_plan_table
from vital_check import extract_vital_check, make_vital_check_table
from lab import extract_lab_data_all, extract_lab_table_date, extract_lab_data_via_interval_info, extract_lab_data, make_lab_table
from main import *

context = []

pdf_path = "/Users/sinequanon/Documents/PerfectS/data/pdf_data/TEST_05.pdf"

pages = load_pdf(pdf_path)
lab_tables = get_lab(pages)

len(lab_tables)
# Out:
# 14

# %%
animal_info = get_animal_data(pages)
print(animal_info)
# Out:
# {'name': '꼬마', 'breed': '개', 'sex': '중성화 Female', 'species': '포메라니안', 'birth': '2018-08-01', 'weight': '1.73 Kg', 'protector': '곽보경(온양발리)'}

# %%
import pandas as pdf_path

results = []

for item in lab_tables:
    if 'RBC' in item['table']['검사명'].values:
        results.append({'date': item['date'], 'table':item['table']})

# %%
results
# Out:
# [{'date': '2023-03-17',
#   'table':           검사명   결과값    단위 status   MIN    MAX Description
#   0         RBC  7.51  None         5.65   8.87        None
#   1         HCT  49.4  None         37.3   61.7        None
#   2         HGB  16.4  None         13.1   20.5        None
#   3         MCV  65.8  None         61.6   73.5        None
#   4         MCH  21.8  None         21.2   25.9        None
#   5        MCHC  33.2  None         32.0   37.9        None
#   6         RDW  16.9  None         13.6   21.7        None
#   7      %RETIC   0.3  None   None  None   None        None
#   8       RETIC  22.5  None         10.0  110.0        None
#   9   RETIC-HGB  23.8  None         22.3   29.6        None
#   10        WBC  6.33  None         5.05  16.76        None
#   11       %NEU  64.7  None   None  None   None        None
#   12       %LYM  23.2  None   None  None   None        None
#   13      %MONO   5.8  None   None  None   None        None
#   14       %EOS   6.0  None   None  None   None        None
#   15        EOS  0.38  None         0.06   1.23        None
#   16      %BASO   0.3  None   None  None   None        None
#   17        NEU  4.09  None         2.95  11.64        None
#   18        LYM  1.47  None         1.05   5.10        None
#   19       MONO  0.37  None         0.16   1.12        None
#   20       BASO  0.02  None         0.00   0.10        None
#   21        PLT   493  None      ▲   148    484        None
#   22        MPV  13.0  None          8.7   13.2        None
#   23        PDW  13.6  None          9.1   19.4        None
#   24        PCT  0.64  None      ▲  0.14   0.46        None}]

# %%
soap_result = get_soap(pages)
soap_result[0]['subjective']
# Out:
# ['Subjective',
#  'CC: 좌측 후지파행 Rad(E)',
#  '[초진] 좌측 후지파행',
#  'S) 주호소)',
#  '어렸을때 좌측 후지 수술했는데 어떤수술인지는 모르심',
#  '> 우측 fhno 한 것으로 확인',
#  '수술후에는 잘 걸었음',
#  '1~2개월전부터 좌측 후지 힘을 덜주는것 같음',
#  '2주전 목욕 맡기고나서 조금 심해짐',
#  '히스토리)',
#  '1. 복용중인 약:- 2. 접종이력: 3. 수술(마취 이력): 8개월쯤 우측 fhno 4. 사고/중독이력: 5. 실내/실외: 6. 사료:',
#  '금식:',
#  '전신상태)',
#  '1. 식이, 음수, 배변, 배뇨: 2. 피부: 3. 호흡: 4. 근육/관절: 슬개골 탈구 좌측 3기, 우측 2기 5. 심장: 6. 방광: 7. 기타:',
#  '검사계획)',
#  '신체검사, 신경계평가 , CBC, 혈청, 가스분석, 복부초음파 , 심초음파, 뇨검사, CT, MRI, 세침흡인검사 , 생검',
#  '검사전 처치)',
#  '수액, 산소, 진통, 이뇨제, CPR',
#  'O)',
#  '신체검사)',
#  '1. BCS: 3/9 2. 심박 : 호흡수 : 3. 수화상태 : 4. 체표림프절 : 5. 청진:nrf 6. 혈압 : 7. 슬개골탈구 : 8. 방광촉진: 9. ETC.:',
#  '혈액검사(주요소견만 )',
#  '1. CBC 2. Biochemistry 1. 3. Blood gas 1.',
#  '영상검사)',
#  '방사선 : bilateral MPL, 양쪽 관절 부종 소견 명확하지않음',
#  'Rad)Hindlimb#름 - 좌측 고관절 subluxation, 경미한 DJD - 양측 MPL - 양측 근육 위축',
#  '심전도)',
#  '1.',
#  '신체검사)',
#  '보행시 경미한 좌측 후지 파행',
#  '서있을때 힘을 덜주는 양상',
#  'back pain-',
#  '후지신경반응 정상',
#  '장요근 통증-',
#  '슬개골 내측 탈구 Lt 3기 Rt 2기(왼쪽은 탈구시 체중지지 잘 못함)',
#  'drawer Lt+, Rt-',
#  '고관절 rom 정상, 통증-',
#  'ortolani Lt+',
#  '신경계평가 )',
#  '1. 시진: 2. 의식: 3. 자세: 4. 뇌신경: 5. 척수: 6. ETC: 7. 의심부위',
#  'CT, MRI)',
#  '1. 촬영 의뢰 부위: 2. CT 3. MRI 4. 세침흡인 및 생검 부위 :',
#  '뇌척수액검사 )',
#  '1. 색상: 2. TP: 3. TNCC: 4. Cytology : 5. C&S/PCR: 6. Comment :',
#  'A; Problem list',
#  '1.',
#  '치료)',
#  '1.',
#  '수액)',
#  '1. 종류: H/S, H/D, D5S, 1/2S, 1/2S+1/2D5W, D5W 2. 속도: 3. 시간.: 4. 첨가제.:',
#  '내복약) () 일간, 식전/식후/식간, 가루/정제/캡슐, 오전오후구분',
#  '1. mg/kg BID',
#  '사료&영양제)',
#  '1.',
#  '연고 & 샴푸)',
#  '1.',
#  '입원중 모니터링) 항목 및 주기설정',
#  '1. 체중 2. TPR 3. 혈압 4. 혈액검사',
#  'P)',
#  '금요일 술전 입원, 토요일 수술예정',
#  'CE)',
#  '양쪽 슬개골 내측 탈구로 왼쪽이 더 심한 양상, 탈구시 체중 지지 어려워함',
#  '왼쪽은 신체검사상 십자인대 불안정성 확인되나 방사사선상 뚜렷한 부종소견 보이지않아 관절낭 절개시 확인 필요',
#  '왼쪽 고관절 탈구되기 쉬운 상태로 주의 필요',
#  'Chart Image']

# %%
print(soap_result[1]['date'])
print(soap_result[3]['plan'])
# Out:
# 2023-03-13 16:10
# [                                                 코드  \
# 0                                             B1003
# 1                                             B1004
# 2                                             B1000
# 3                                             B4032
# 4                                             B4036
# 5                                             c3036
# 6                                             c3000
# 7                                             c3006
# 8                                             D6008
# 9                                             D6011
# 10                                            D6007
# 11                                            c6018
# 12                                           Ba2004
# 13                                            c3001
# 14                                           Dg1007
# 15                                           Ca4009
# 16                                           Ca4002
# 17                                            c1064
# 18                                            c2001
# 19                                            c6071
# 20  Da1044 8806599010329 펜타듀르패취12ug/h(펜타닐) (1.375㎎)
# 21                      8806422007021 부광미다졸람주사 (5㎖)
# 22                                       2022-80191
#
#                                 항목명    수량    일투    일수    총투 Route  Dose
# 0        혈액화학검사(chemistry)_17항 목_혈액   1 회  None  None  None  None  None
# 1                       전해질/가스검사_혈액   1 회  None  None  None  None  None
# 2              혈구검사(CBC_Procyte)_혈액   1 회  None  None  None  None  None
# 3                         혈압검사(도플러)   1 회  None  None  None  None  None
# 4             심전도검사(Cardiobird ECG)   1 회  None  None  None  None  None
# 5                           정맥카테터장착   1 회  None  None  None  None  None
# 6                               채혈비   1 회  None  None  None  None  None
# 7                            마취모니터링   1 회  None  None  None  None  None
# 8                       일회용 수술복(2벌)   1 회  None  None  None  None  None
# 9                           일회용 수술포   1 회  None  None  None  None  None
# 10                          아이오반 필름   1 회  None  None  None  None  None
# 11                         넥카라_15cm   1 회  None  None  None  None  None
# 12            방사선(X-ray)_1컷 추가_10kg   6 회  None  None  None  None  None
# 13             흡입마취_Isoflurane_10kg   1 회  None  None  None  None  None
# 14             탈구3기이하(MPL)_슬개골_10kg   2 회  None  None  None  None  None
# 15              입원A(수액,주사)_24h_10kg   3 회  None  None  None  None  None
# 16                  입원(단독)_24h_10kg   4 회  None  None  None  None  None
# 17                 주사(진통)_멜록시캄_10kg   3 회  None  None  None  None  None
# 18                    내복약_1일2회_10kg   7 회  None  None  None  None  None
# 19  진통제_펜타닐패치(마약류, 72시간, 12ug/h)_1장   1 회  None  None  None  None  None
# 20                  중성화수술추가_암컷_10kg   1 회  None  None  None  None  None
# 21                             None  None     1  None  None  None  None
# 22             프리폴-엠시티주(프로포폴) (20㎖)  None  None  None  None    IV  None  ]

# %%
vital_check = get_vital_check(pages)
print(vital_check)
# Out:
#            날짜     시간 BW(Kg) BT(C) BP(mmHg) HR(/min) Sign
# 0  2023-03-17  17:54    1.9    40      110        0  장아람
# 1  2023-03-20  15:00      0  38.6        0        0  장아람
# 2  2023-03-21  15:11    1.8     0        0        0  곽민석
# 3  2023-03-22  15:27   1.83  38.2        0        0  정유정
# 4  2023-03-23  14:58   1.86     0        0        0  정소원
# 5  2023-04-06  19:14    1.8  39.8      130        0  양준우
# 6  2023-04-10  15:49   1.71  37.7        0        0  곽민석
# 7  2023-04-23  17:02   1.73     0        0        0  이예성
