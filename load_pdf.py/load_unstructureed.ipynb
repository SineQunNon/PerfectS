# %%
# !pip install unstructured unstructured-inference
# Out:
# Requirement already satisfied: unstructured in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (0.10.19)
# Requirement already satisfied: unstructured-inference in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (0.6.6)
# Requirement already satisfied: chardet in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (5.2.2)
# Requirement already satisfied: nltk in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: requests in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (2.12.1)
# Requirement already satisfied: dataclasses-json in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (2024.4.27)
# Requirement already satisfied: langdetect in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (0.3.4)
# Requirement already satisfied: python-multipart in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (0.0.9)
# Requirement already satisfied: huggingface-hub in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (0.22.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (4.10.0.82)
# Requirement already satisfied: onnx==1.14.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (1.14.1)
# Requirement already satisfied: onnxruntime in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (1.18.0)
# Requirement already satisfied: transformers>=4.25.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (4.40.2)
# Requirement already satisfied: rapidfuzz in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from unstructured-inference) (3.9.3)
# Requirement already satisfied: protobuf>=3.20.2 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from onnx==1.14.1->unstructured-inference) (4.25.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from onnx==1.14.1->unstructured-inference) (4.12.2)
# Requirement already satisfied: filelock in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference) (3.15.1)
# Requirement already satisfied: packaging>=20.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured-inference) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from huggingface-hub->unstructured-inference) (2024.6.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from dataclasses-json->unstructured) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from langdetect->unstructured) (1.16.0)
# Requirement already satisfied: scipy in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (1.13.1)
# Requirement already satisfied: pandas in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.2.2)
# Requirement already satisfied: pillow in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (10.3.0)
# Requirement already satisfied: iopath in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (0.1.10)
# Requirement already satisfied: pdfplumber in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (0.11.1)
# Requirement already satisfied: pdf2image in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (1.17.0)
# Requirement already satisfied: torch in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.2.2)
# Requirement already satisfied: torchvision in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (0.17.2)
# Requirement already satisfied: effdet in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (0.4.1)
# Requirement already satisfied: pytesseract in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference) (0.3.10)
# Requirement already satisfied: click in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: coloredlogs in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from onnxruntime->unstructured-inference) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from onnxruntime->unstructured-inference) (24.3.25)
# Requirement already satisfied: sympy in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from onnxruntime->unstructured-inference) (1.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from requests->unstructured) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from requests->unstructured) (2024.6.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from coloredlogs->onnxruntime->unstructured-inference) (10.0)
# Requirement already satisfied: timm>=0.9.2 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (1.0.3)
# Requirement already satisfied: pycocotools>=2.0.2 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.0.8)
# Requirement already satisfied: omegaconf>=2.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.3.0)
# Requirement already satisfied: networkx in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference) (3.3)
# Requirement already satisfied: jinja2 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference) (3.1.4)
# Requirement already satisfied: portalocker in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2024.1)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference) (4.30.0)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference) (42.0.8)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from sympy->onnxruntime->unstructured-inference) (1.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (3.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.1.5)
# Requirement already satisfied: cffi>=1.12 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference) (3.1.2)
# Requirement already satisfied: pycparser in /Users/sinequanon/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference) (2.22)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
from langchain_community.document_loaders import UnstructuredPDFLoader
import re

# %%
pdf_filepath = '/Users/sinequanon/Desktop/Capstone/data/pdf_data/TEST_01.pdf'

loader = UnstructuredPDFLoader(pdf_filepath)

pages = loader.load()

len(pages)
# Out:
# 1

# %%
loader = UnstructuredPDFLoader(pdf_filepath, mode='elements')
pages = loader.load()

len(pages)

print(f"pages[0] : {pages[0].page_content, pages[0].metadata['coordinates']['points']}")
print(f"pages[1] : {pages[1].page_content, pages[1].metadata['coordinates']['points']}")
print(f"pages[2] : {pages[2].page_content, pages[2].metadata['coordinates']['points']}")
print(f"pages[3] : {pages[3].page_content, pages[3].metadata['coordinates']['points']}")
print(f"pages[4] : {pages[4].page_content, pages[4].metadata['coordinates']['points']}")
print(f"pages[5] : {pages[5].page_content, pages[5].metadata['coordinates']['points']}")
print(f"pages[6] : {pages[6].page_content, pages[6].metadata['coordinates']['points']}")
print(f"pages[7] : {pages[7].page_content, pages[7].metadata['coordinates']['points']}")
print(f"pages[8] : {pages[8].page_content, pages[8].metadata['coordinates']['points']}")
print(f"pages[9] : {pages[9].page_content, pages[9].metadata['coordinates']['points']}")
print(f"pages[10] : {pages[10].page_content, pages[10].metadata['coordinates']['points']}")
print(f"pages[11] : {pages[11].page_content, pages[11].metadata['coordinates']['points']}")
print(f"pages[12] : {pages[12].page_content, pages[12].metadata['coordinates']['points']}")
print(f"pages[13] : {pages[13].page_content, pages[13].metadata['coordinates']['points']}")
print(f"pages[14] : {pages[14].page_content, pages[14].metadata['coordinates']['points']}")
print(f"pages[15] : {pages[15].page_content, pages[15].metadata['coordinates']['points']}")
print(f"pages[16] : {pages[16].page_content, pages[16].metadata['coordinates']['points']}")
print(f"pages[17] : {pages[17].page_content, pages[17].metadata['coordinates']['points']}")
print(f"pages[18] : {pages[18].page_content, pages[18].metadata['coordinates']['points']}")
print(f"pages[19] : {pages[19].page_content, pages[19].metadata['coordinates']['points']}")
print(f"pages[20] : {pages[20].page_content, pages[20].metadata['coordinates']['points']}")
print(f"pages[21] : {pages[21].page_content, pages[21].metadata['coordinates']['points']}")
print(f"pages[22] : {pages[22].page_content, pages[22].metadata['coordinates']['points']}")
print(f"pages[23] : {pages[23].page_content, pages[23].metadata['coordinates']['points']}")
print(f"pages[24] : {pages[24].page_content, pages[24].metadata['coordinates']['points']}")
print(f"pages[25] : {pages[25].page_content, pages[25].metadata['coordinates']['points']}")
# Out:
# pages[0] : ('Medical Record', ((30.35, 47.648000000000025), (30.35, 87.44799999999998), (310.4226, 87.44799999999998), (310.4226, 47.648000000000025)))
# pages[1] : ('보호자번호:', ((30.35, 107.39999999999998), (30.35, 115.30000000000007), (71.91189999999999, 115.30000000000007), (71.91189999999999, 107.39999999999998)))
# pages[2] : ('1066721721', ((78.54, 107.00999999999999), (78.54, 115.90999999999997), (127.49000000000001, 115.90999999999997), (127.49000000000001, 107.00999999999999)))
# pages[3] : ('보호자이름:', ((166.41, 107.39999999999998), (166.41, 115.30000000000007), (207.9719, 115.30000000000007), (207.9719, 107.39999999999998)))
# pages[4] : ('전경진(zoo)', ((214.6, 107.00999999999999), (214.6, 115.90999999999997), (261.4763, 115.90999999999997), (261.4763, 107.00999999999999)))
# pages[5] : ('전화번호: 010-9959-3371', ((288.3, 107.20000000000005), (288.3, 116.10000000000002), (389.12300000000005, 116.10000000000002), (389.12300000000005, 107.20000000000005)))
# pages[6] : ('울산24시S동물메디컬센터(울산)', ((427.2, 111.04999999999995), (427.2, 119.94999999999993), (555.6893, 119.94999999999993), (555.6893, 111.04999999999995)))
# pages[7] : ('주소:', ((30.35, 124.40999999999997), (30.35, 132.31000000000006), (48.21190000000001, 132.31000000000006), (48.21190000000001, 124.40999999999997)))
# pages[8] : ('울산광역시 북구 염포로 645 (염포동, 현대아파트) 1동~7동 2동 401호', ((78.54, 124.00999999999999), (78.54, 132.90999999999997), (357.0388000000001, 132.90999999999997), (357.0388000000001, 124.00999999999999)))
# pages[9] : ('052-707-2475', ((427.2, 132.85000000000002), (427.2, 141.75), (483.448, 141.75), (483.448, 132.85000000000002)))
# pages[10] : ('동물번호:', ((30.35, 141.41999999999996), (30.35, 149.32000000000005), (64.0119, 149.32000000000005), (64.0119, 141.41999999999996)))
# pages[11] : ('종류:', ((30.35, 158.41999999999996), (30.35, 166.32000000000005), (48.21190000000001, 166.32000000000005), (48.21190000000001, 158.41999999999996)))
# pages[12] : ('2029432', ((78.54, 141.01999999999998), (78.54, 149.91999999999996), (112.805, 149.91999999999996), (112.805, 141.01999999999998)))
# pages[13] : ('개', ((78.54, 158.02999999999997), (78.54, 166.92999999999995), (87.44000000000001, 166.92999999999995), (87.44000000000001, 158.02999999999997)))
# pages[14] : ('동물이름:', ((225.94, 141.41999999999996), (225.94, 149.32000000000005), (259.6019, 149.32000000000005), (259.6019, 141.41999999999996)))
# pages[15] : ('품종:', ((225.94, 158.3599999999999), (225.94, 166.26), (243.80190000000002, 166.26), (243.80190000000002, 158.3599999999999)))
# pages[16] : ('모찌', ((265.62, 141.01999999999998), (265.62, 149.91999999999996), (283.41999999999996, 149.91999999999996), (283.41999999999996, 141.01999999999998)))
# pages[17] : ('몰티즈', ((265.62, 157.96000000000004), (265.62, 166.86), (292.32, 166.86), (292.32, 157.96000000000004)))
# pages[18] : ('울산광역시 남구 삼산로 160 (달동) 스타타워', ((427.2, 147.01999999999998), (427.2, 166.41999999999996), (540.2834, 166.41999999999996), (540.2834, 147.01999999999998)))
# pages[19] : ('성별:', ((30.35, 175.37), (30.35, 183.2700000000001), (48.21190000000001, 183.2700000000001), (48.21190000000001, 175.37)))
# pages[20] : ('중성화 Male', ((78.54, 174.97000000000003), (78.54, 183.87), (128.10410000000002, 183.87), (128.10410000000002, 174.97000000000003)))
# pages[21] : ('생일:', ((225.94, 175.37), (225.94, 183.2700000000001), (243.80190000000002, 183.2700000000001), (243.80190000000002, 175.37)))
# pages[22] : ('2015-10-17', ((265.62, 174.97000000000003), (265.62, 183.87), (312.078, 183.87), (312.078, 174.97000000000003)))
# pages[23] : ('색상:', ((30.35, 193.13), (30.35, 201.0300000000001), (48.21190000000001, 201.0300000000001), (48.21190000000001, 193.13)))
# pages[24] : ('RFID:', ((225.94, 192.43999999999994), (225.94, 200.34000000000003), (245.6347, 200.34000000000003), (245.6347, 192.43999999999994)))
# pages[25] : ('현재체중:', ((30.35, 209.44999999999993), (30.35, 217.35000000000002), (64.0119, 217.35000000000002), (64.0119, 209.44999999999993)))

# %%
pages[10]
# Out:
# Document(page_content='동물번호:', metadata={'source': '/Users/sinequanon/Desktop/Capstone/data/pdf_data/TEST_01.pdf', 'coordinates': {'points': ((30.35, 141.41999999999996), (30.35, 149.32000000000005), (64.0119, 149.32000000000005), (64.0119, 141.41999999999996)), 'system': 'PixelSpace', 'layout_width': 595.5, 'layout_height': 842.25}, 'filename': 'TEST_01.pdf', 'file_directory': '/Users/sinequanon/Desktop/Capstone/data/pdf_data', 'last_modified': '2024-07-19T15:00:53', 'filetype': 'application/pdf', 'page_number': 1, 'links': [], 'category': 'Title'})

# %%
'''
동물이름

'''
# Out:
# '\n동물이름\n\n'

# %%
pdf_filepath = '/Users/sinequanon/Desktop/Capstone/data/pdf_data/TEST_01.pdf'

loader = UnstructuredPDFLoader(pdf_filepath, mode='elements')
pages = loader.load()

len(pages)
# Out:
# 861

# %%
print(pages[0].metadata['coordinates']['points'][0][0])
print(pages[0].metadata['coordinates']['points'][0][1])
# Out:
# 30.35
# 47.648000000000025

# %% [markdown]
# # 동물 정보 및 보호자 정보 추출
#
# unstructuredPDFLoader 사용

# %%
pdf_filepath = '/Users/sinequanon/Desktop/Capstone/data/pdf_data/TEST_01.pdf'

loader = UnstructuredPDFLoader(pdf_filepath, mode='elements')
pages = loader.load()

len(pages)

def extract_data_via_points(pages, x, y1, y2):
    for page in pages:
        metadata = page.metadata
        coordinates = metadata['coordinates']

        if metadata['page_number'] == 1 and coordinates['points'][0][0] == x\
            and coordinates['points'][0][1] > y1 \
                and coordinates['points'][1][1] < y2:
            return page.page_content
    
    return ("Not Found")

def get_animal_data(pdf_path):
    pdf_filepath = pdf_path
    loader = UnstructuredPDFLoader(pdf_filepath, mode='elements')
    pages = loader.load()

    info = {}

    #동물 정보 추출
    info['name'] = extract_data_via_points(pages, 265.62, 141, 150)
    info['breed'] = extract_data_via_points(pages, 78.54, 158, 167)
    info['sex'] = extract_data_via_points(pages, 78.54, 174, 184)
    info['species'] = extract_data_via_points(pages, 265.62, 157, 167)
    info['birth'] = extract_data_via_points(pages, 265.62, 174, 184)
    info['weight'] = extract_data_via_points(pages, 78.54, 209, 218)
    
    # 보호자 이름 추출
    info['protector'] = extract_data_via_points(pages, 214.6, 107, 116)

    return info

# %%
info_ = get_animal_data("/Users/sinequanon/Desktop/Capstone/data/pdf_data/TEST_01.pdf")
print(info_)
# Out:
# {'name': '모찌', 'breed': '개', 'sex': '중성화 Male', 'species': '몰티즈', 'birth': '2015-10-17', 'weight': '5 Kg', 'protector': '전경진(zoo)'}

# %%
info_ = get_animal_data("/Users/sinequanon/Desktop/Capstone/data/pdf_data/TEST_01.pdf")
print(info_)
# Out:
# {'name': '모찌', 'breed': '개', 'sex': '중성화 Male', 'species': '몰티즈', 'birth': '2015-10-17', 'weight': '5 Kg', 'protector': '전경진(zoo)'}

# %% [markdown]
# ## Subjective 추출
#
# YYYY-MM-DD HH:MM y 위치, 페이지 ~ 다음 YYYY-MM-DD HH:MM \
# y위치, 페이지 사이 데이터 일단 다 뽑기
# Subjective

# %% [markdown]
# ## 진료 날짜 및 시간 추출
#
# - 마지막 날짜 관련된 것은 Vital Check 기준으로 하기

# %%
import numpy as np
import re


"""
\d{4}-\d{2}-\d{2} \d{2}:\d{2} 영역 구하기

출력 : 2차원 numpy배열 ['날짜', 'y 좌표 값', '페이지 번호']
"""
def extract_date_position(pages):
    date_time_pattern = re.compile(r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}")

    date = []
    date_points = []
    date_pages = []


    for page in pages:
        metadata = page.metadata
        coordinates = metadata['coordinates']

        matches = date_time_pattern.findall(page.page_content)
        x_point = coordinates['points'][0][0]
        y_height = coordinates['points'][1][1] - coordinates['points'][0][1]
        
        if matches and x_point == 30.35 and y_height > 8:
            #print(page.page_content, "points:", coordinates['points'])
            date.append(page.page_content)
            date_points.append(coordinates['points'][1][1])
            date_pages.append(metadata['page_number'])

    for page in pages:
        metadata = page.metadata
        coordinates = metadata['coordinates']

        x_point = coordinates['points'][0][0]
        y_height = coordinates['points'][1][1] - coordinates['points'][0][1]

        if page.page_content.lower() == 'vital check' and x_point == 33.35 and y_height > 20:
            date.append(page.page_content)
            date_points.append(coordinates['points'][0][1])
            date_pages.append(metadata['page_number'])

    result = np.column_stack((date, date_points, date_pages))

    return result

# %% [markdown]
# ### 날짜 데이터와 날짜 데이터 사이의 데이터 추출하기

# %%
"""
입력
Document 데이터
추출하고자 하는 영역의 시간 시작 위치 및 페이지 / 끝나는 위치 및 페이지 

출력
추출하려는 데이터 및 메타데이터
"""

def extract_data_via_interval_info(pages, interval_info):
    extracted_pages = []
    start_y_point = float(interval_info[0][0])
    end_y_point = float(interval_info[1][0])
    start_page = int(interval_info[0][1])
    end_page = int(interval_info[1][1])

    if end_page == 0:
        # Vital Check 기준으로 일단 추출해볼까..
        pass
    else:
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            #같은 페이지인 경우
            if start_page == end_page:
                if metadata['page_number'] == start_page and points[0][1] > start_y_point and points[1][1] < end_y_point:
                    extracted_pages.append(page)
            # 다른 페이지인 경우
            else:
                if metadata['page_number'] > start_page and metadata['page_number'] < end_page:
                    extracted_pages.append(page)
                if metadata['page_number'] == start_page and points[0][1] > start_y_point:
                    extracted_pages.append(page)
                if metadata['page_number'] == end_page and points[1][1] < end_y_point:
                    extracted_pages.append(page)

    return extracted_pages

# %% [markdown]
# ### Subjective 안에서 Plan 또는 Assessment 데이터를 제외하고 추출

# %%
def extract_subjective_data(pages):
    # Plan과 Accessment y값과 page 추출
    extracted_pages = []
    min_page = 50000
    min_height = 50000.0
    for page in pages:
        metadata = page.metadata
        points = metadata['coordinates']['points']
        text = page.page_content

        if (text.lower() == 'plan' or text.lower() =='assessment') and points[0][0]==36.02:
            if metadata['page_number'] <= min_page:
                min_page = metadata['page_number']
                min_height = min(min_height, points[0][1])
    
    # Plan과 Assessment를 제외한 값 추출
    for page in pages:
        metadata = page.metadata
        points = metadata['coordinates']['points']
        page_num = metadata['page_number']
        y_point = points[0][1]

        # 페이지가 같거나 작은 경우 데이터를 추출
        if page_num < min_page:
            extracted_pages.append(page)
        elif page_num == min_page and y_point < min_height:
            extracted_pages.append(page)
    
    return extracted_pages

# %% [markdown]
# ### Plan 데이터 추출하기
#
# - 테이블로 추출

# %%
import pandas as pd
#Plan 데이터가 존재하는지 확인
def plan_exists(pages):
    page_num = 0
    y_point = 0
    for page in pages:
        if page.page_content.lower() == '코드' and page.metadata['coordinates']['points'][0][0] == 30.35:
            #Plan y : 36.02
            page_num = page.metadata['page_number']
            y_point = page.metadata['coordinates']['points'][1][1]
    
    if page_num == 0 and y_point == 0:
        return False, page_num, y_point
    else:
        return True, page_num, y_point

# 플랜 내용만 다 추출
def extract_plan_data(pages):
    is_check, plan_page_num, plan_y_point = plan_exists(pages)
    
    plan_data = []
    
    if is_check:
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if metadata['page_number'] == plan_page_num and points[0][1] >= plan_y_point:
                plan_data.append(page)
            elif metadata['page_number'] > plan_page_num:
                plan_data.append(page)

        return plan_data
    else:
        return False
    
def make_plan_table(pages):
    plan = {
        "코드" : [],
        "항목명" : [],
        "수량" : [],
        "일투" : [],
        "일수" : [],
        "총투" : [],
        "Route" : [],
        "Dose" : [],
    }

    """
    표 구하는 법
    코드 값 먼저 추출 -> y값과 각 열의 x값 일치하는 항목 검색 -> 존재하면 검색 결과 값 넣고 없으면 None 추가
    """
    
    # Plan의 항목이 몇 개인지 추출
    y_points = []
    page_info = []
    for page in pages:
        #print(page)
        if page.metadata['coordinates']['points'][0][0] == 30.35:
            y_points.append(page.metadata['coordinates']['points'][0][1])
            page_info.append(page.metadata['page_number'])
            plan['코드'].append(page.page_content)

    # print(y_points)
    # print(page_info) 
    for point, page_ in zip(y_points,page_info):
        # 항목명 내용 추출
        # 항목명 104.05, 130.75
        not_present = True
        max_point = 0
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']
            
            
            if points[0][0] == 104.05 and points[0][1] > (point - 4.0) and points[0][1] < (point + 4.0) and metadata['page_number'] == page_:
                plan['항목명'].append(page.page_content)
                max_point = max(max_point, points[2][0])
                not_present = False
        if not_present:
            plan['항목명'].append(None)
    
    
        # 수량 내용 추출
        # 수량 274.96, 292.75999999999993
        not_present = True
        max_point = max(271.96, max_point)
        
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > max_point and points[0][0] < 338 and points[0][1] > (point - 4.0) and points[0][1] < (point + 4.0) and metadata['page_number'] == page_:
                plan['수량'].append(page.page_content)
                max_point = max(max_point, points[2][0])
                not_present = False
        if not_present:
            plan['수량'].append(None)
        
        # 일투 338.74, 356.53999999999996 = 약 17
        max_point = min(338.74, max_point)
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > max_point and points[0][0] < 368 and points[0][1] > (point - 4.0) and points[0][1] < (point + 4.0) and metadata['page_number'] == page_:
                plan['일투'].append(page.page_content)
                max_point = max(max_point, points[2][0])
                not_present = False
        if not_present:
            plan['일투'].append(None)

        max_point = min(369.93, max_point)
        # 일수 총투 369.93, 387 
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > max_point and points[0][0] < 390 and points[0][1] > (point - 4.0) and points[0][1] < (point + 4.0) and metadata['page_number'] == page_:
                plan['일수'].append(page.page_content)
                max_point = max(max_point, points[2][0])
                not_present = False
        if not_present:
            plan['일수'].append(None)

        # 총투 403, 420.31999999999994
        max_point = min(max_point, 403)
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > max_point and points[0][0] < 430 and points[0][1] > (point - 4.0) and points[0][1] < (point + 4.0) and metadata['page_number'] == page_:
                plan['총투'].append(page.page_content)
                max_point = max(max_point, points[2][0])
                not_present = False
        if not_present:
            plan['총투'].append(None)

        
        # Route 442.79, 467.82570000000004
        not_present = True
        max_point = min(max_point, 442.79)
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > max_point and points[0][0] < 467 and points[0][1] > (point - 4.0) and points[0][1] < (point + 4.0) and metadata['page_number'] == page_:
                plan['Route'].append(page.page_content)
                max_point = max(max_point, points[2][0])
                not_present = False
        if not_present:
            plan['Route'].append(None)

        # Dose 514.21, 535.3386
        not_present = True
        max_point = max(max_point, 514.21)
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > max_point and points[0][0] < 560 and points[0][1] > (point - 4.0) and points[0][1] < (point + 4.0) and metadata['page_number'] == page_:
                plan['Dose'].append(page.page_content)
                max_point = max(max_point, points[2][0])
                not_present = False
        if not_present:
            plan['Dose'].append(None)
        

    plan_df = pd.DataFrame(plan)

    return plan_df

# %% [markdown]
# ## Assessment 데이터 추출하기
#
# - 구분 (30.35, 418.82), (30.35, 427.71999999999997), (48.15, 427.71999999999997), (48.15, 418.82)
# - 코드 (92.71, 418.82), (92.71, 427.71999999999997), (110.51, 427.71999999999997), (110.51, 418.82)
# - 진단명 (183.42, 418.82), (183.42, 427.71999999999997), (210.12, 427.71999999999997), (210.12, 418.82)
# - 과목 (387.51, 418.82), (387.51, 427.71999999999997), (405.30999999999995, 427.71999999999997), (405.30999999999995, 418.82)
# - Sign (526.92, 418.82), (526.92, 427.71999999999997), (545.3607999999999, 427.71999999999997), (545.3607999999999, 418.82)

# %%
#Assessment 데이터가 존재하는지 확인
#존재한다면 페이지 번호와 y 위치 추출
def assessment_exists(pages):
    page_num = 0
    y_point = 0
    for page in pages:
        if page.page_content.lower() == '구분' and page.metadata['coordinates']['points'][0][0] == 30.35:
            #Plan y : 36.02
            page_num = page.metadata['page_number']
            y_point = page.metadata['coordinates']['points'][1][1]
    
    if page_num == 0 and y_point == 0:
        return False, page_num, y_point
    else:
        return True, page_num, y_point

def plan_exists_for_assessment(pages):
    page_num = 0
    y_point = 0
    for page in pages:
        if page.page_content.lower() == 'plan' and page.metadata['coordinates']['points'][0][0] == 36.02:
            #Plan y : 36.02
            page_num = page.metadata['page_number']
            y_point = page.metadata['coordinates']['points'][0][1]
    
    if page_num == 0 and y_point == 0:
        return False, page_num, y_point
    else:
        return True, page_num, y_point

# 평가 내용만 다 추출
def extract_assessment_data(pages):
    is_check, assessment_page_num, assessment_y_point = assessment_exists(pages)
    plan_is_check, plan_page_num, plan_y_point = plan_exists_for_assessment(pages)
    assessment_data = []
    
    if is_check and plan_is_check: # 플랜 데이터 위로 추출
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']
            page_number = metadata['page_number']

            if assessment_page_num == plan_page_num:
                if page_number == assessment_page_num and points[0][1] >= assessment_y_point and points[0][1] < plan_y_point:
                    assessment_data.append(page)
            elif assessment_page_num < plan_page_num:
                if page_number == assessment_page_num and points[0][1] >= assessment_y_point:
                    assessment_data.append(page)
                elif page_number == plan_page_num and points[0][1] < plan_y_point:
                    assessment_data.append(page)
                elif page_number > assessment_page_num and page_number < plan_page_num:
                    assessment_data.append(page)
        return assessment_data
    elif is_check: # Plan 데이터가 존재하지 않을 때
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']
            page_number = metadata['page_number']

            if page_number == assessment_page_num and points[0][1] >= assessment_y_point:
                if page_number == assessment_page_num:
                    assessment_data.append(page)
            elif page_number > assessment_page_num :
                assessment_data.append(page)
                
        return assessment_data
    else:
        return False
    

def make_assessment_table(pages):
    assessment = {
        "구분" : [],
        "코드" : [],
        "진단명" : [],
        "과목" : [],
        "Sign" : []
    }
    
    y_points = []
    page_info = []
    for page in pages:
    #print(page)
        if page.metadata['coordinates']['points'][0][0] == 30.35:
            y_points.append(page.metadata['coordinates']['points'][0][1])
            page_info.append(page.metadata['page_number'])
            assessment['구분'].append(page.page_content)
    
    for point, page_ in zip(y_points, page_info):
        
        # 코드 92.71
        #not_present = True
        max_point = 0


        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']
            
            if points[0][0] == 92.71 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                assessment['코드'].append(page.page_content)
                not_present = False

        # 진단명 (183.42, 418.82), (183.42, 427.71999999999997), (210.12, 427.71999999999997), (210.12, 418.82)
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] == 183.42 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                assessment['진단명'].append(page.page_content)
        
        # 과목
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] == 387.51 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                max_point = max(points[2][0], 387.51)
                assessment['과목'].append(page.page_content)
        
        # Sign
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > max_point and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                assessment['Sign'].append(page.page_content)
                not_present = False
        if not_present:
            assessment['Sign'].append(None)
    
    assessment_df = pd.DataFrame(assessment)
    return assessment_df
# Out:
#   Cell In[118], line 132
#     assessment_df = pd.DataFrame(assessment)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 130

# %% [markdown]
# ## Subjective 데이터 추출 Main

# %%
import numpy as np
from langchain_community.document_loaders import UnstructuredPDFLoader
import re

pdf_filepath = '/Users/sinequanon/Desktop/PerfectS/data/pdf_data/TEST_05.pdf'

loader = UnstructuredPDFLoader(pdf_filepath, mode='elements')
pages = loader.load()

data = extract_date_position(pages)

#print(date_data)

#data = np.append(date_data, [[0,0,0]], axis=0)
#print(data)
for i in range(len(data)-1):
    subjective_one = {
        "date" : '',
        "subjective" : [],
        "assessment" : [],
        "plan" : []
    }

    y_point = []
    page_num = []

    # 데이터 찾을 시작 위치 정보 저장
    y_point.append(data[i][1])
    page_num.append(data[i][2])
    y_point.append(data[i+1][1])
    page_num.append(data[i+1][2])
    
    
    interval_info = np.column_stack((y_point, page_num))

    # 날짜 별로 추출 / 안에 존재하는 데이터 모두
    extracted_pages = extract_data_via_interval_info(pages, interval_info)
    
    subjective_data = extract_subjective_data(extracted_pages)
    
    
    subjective_one['date'] = data[i][0]
    for page in subjective_data:
        subjective_one['subjective'].append(page.page_content)
    
    #print(subjective_one)
    
    # 평가 데이터 추출
    assessment_data = extract_assessment_data(extracted_pages)
    
    #print(assessment_data)
    if assessment_data:
        for page in assessment_data:
            print(page.page_content)
    if assessment_data:
        assessment_table = make_assessment_table(assessment_data)
        subjective_one['assessment'].append(assessment_table)

        
        
    
        
    
    #print(subjective_one)
    

    #Plan 위치 정보 추출
    plan_data = extract_plan_data(extracted_pages)
    
    # # Plan 정보 표로 만들기
    if plan_data:
        plan_table = make_plan_table(plan_data)
        subjective_one['plan'].append(plan_table)
    
    print(subjective_one)
    #     #print(plan_table)
    #     plan_table.to_csv(f"test{i}.csv", index=True)
        
    #     file_path = f'./plan{i}.txt'
    #     with open(file_path, 'w') as file:
    #         file.write(data[i][0])
    #         file.write('\n')
    #         for page in plan_data:
    #             file.write(page.page_content)
    #             file.write('\n') 


    # file_path = f'./test{i}.txt'
    # with open(file_path, 'w') as file:
    #     file.write(data[i][0])
    #     file.write('\n')
    #     for page in subjective_data:
    #         file.write(page.page_content)
    #         file.write('\n')
            

    #print(extracted_pages)
    #print(type(extracted_pages))
    #print(len(extracted_pages))
# Out:
# {'date': '2023-03-13 15:02', 'subjective': ['Subjective', 'CC: 좌측 후지파행 Rad(E)', '[초진] 좌측 후지파행', 'S) 주호소)', '어렸을때 좌측 후지 수술했는데 어떤수술인지는 모르심', '> 우측 fhno 한 것으로 확인', '수술후에는 잘 걸었음', '1~2개월전부터 좌측 후지 힘을 덜주는것 같음', '2주전 목욕 맡기고나서 조금 심해짐', '히스토리)', '1. 복용중인 약:- 2. 접종이력: 3. 수술(마취 이력): 8개월쯤 우측 fhno 4. 사고/중독이력: 5. 실내/실외: 6. 사료:', '금식:', '전신상태)', '1. 식이, 음수, 배변, 배뇨: 2. 피부: 3. 호흡: 4. 근육/관절: 슬개골 탈구 좌측 3기, 우측 2기 5. 심장: 6. 방광: 7. 기타:', '검사계획)', '신체검사, 신경계평가 , CBC, 혈청, 가스분석, 복부초음파 , 심초음파, 뇨검사, CT, MRI, 세침흡인검사 , 생검', '검사전 처치)', '수액, 산소, 진통, 이뇨제, CPR', 'O)', '신체검사)', '1. BCS: 3/9 2. 심박 : 호흡수 : 3. 수화상태 : 4. 체표림프절 : 5. 청진:nrf 6. 혈압 : 7. 슬개골탈구 : 8. 방광촉진: 9. ETC.:', '혈액검사(주요소견만 )', '1. CBC 2. Biochemistry 1. 3. Blood gas 1.', '영상검사)', '방사선 : bilateral MPL, 양쪽 관절 부종 소견 명확하지않음', 'Rad)Hindlimb#름 - 좌측 고관절 subluxation, 경미한 DJD - 양측 MPL - 양측 근육 위축', '심전도)', '1.', '신체검사)', '보행시 경미한 좌측 후지 파행', '서있을때 힘을 덜주는 양상', 'back pain-', '후지신경반응 정상', '장요근 통증-', '슬개골 내측 탈구 Lt 3기 Rt 2기(왼쪽은 탈구시 체중지지 잘 못함)', 'drawer Lt+, Rt-', '고관절 rom 정상, 통증-', 'ortolani Lt+', '신경계평가 )', '1. 시진: 2. 의식: 3. 자세: 4. 뇌신경: 5. 척수: 6. ETC: 7. 의심부위', 'CT, MRI)', '1. 촬영 의뢰 부위: 2. CT 3. MRI 4. 세침흡인 및 생검 부위 :', '뇌척수액검사 )', '1. 색상: 2. TP: 3. TNCC: 4. Cytology : 5. C&S/PCR: 6. Comment :', 'A; Problem list', '1.', '치료)', '1.', '수액)', '1. 종류: H/S, H/D, D5S, 1/2S, 1/2S+1/2D5W, D5W 2. 속도: 3. 시간.: 4. 첨가제.:', '내복약) () 일간, 식전/식후/식간, 가루/정제/캡슐, 오전오후구분', '1. mg/kg BID', '사료&영양제)', '1.', '연고 & 샴푸)', '1.', '입원중 모니터링) 항목 및 주기설정', '1. 체중 2. TPR 3. 혈압 4. 혈액검사', 'P)', '금요일 술전 입원, 토요일 수술예정', 'CE)', '양쪽 슬개골 내측 탈구로 왼쪽이 더 심한 양상, 탈구시 체중 지지 어려워함', '왼쪽은 신체검사상 십자인대 불안정성 확인되나 방사사선상 뚜렷한 부종소견 보이지않아 관절낭 절개시 확인 필요', '왼쪽 고관절 탈구되기 쉬운 상태로 주의 필요', 'Chart Image'], 'assessment': [], 'plan': [      코드          항목명   수량    일투    일수    총투 Route  Dose
# 0  A1000  진료비_초진_10kg  1 회  None  None  None  None  None]}
# {'date': '2023-03-13 16:10', 'subjective': ['Subjective', 'CC: 수술견적, 인계(아람과장님)', '이번주 금요일 술전입원', '토요일 양측 슬개골, 좌측 십자인대 수술예정', '십자인대는 확인후 괜찮으면 슬개골만 진행', '줄기세포 및 중성화수술 추가는 생각해보고 수술전까지 말씀해주실예정', '금요일 아람과장님 술전입원 예약', '>정원장 방사선 확인 후 코멘트', '좌측 고관절 djd 보임, 십자인대는 이상없을것으로 추정', '현재 좌측후지파행의 원인이 고관절인지 슬관절인지 정확한 진단 필요', '술전 입원시 철저한 신체검사 필요, 좌측tpa뷰 다시 촬영 필요', '슬탈+십자인대 진행시 암중 불가(수술시간 너무 길어짐)', '슬탈 단독 진행시만 암중 가능', '체중 없음, 방사선 판독 제대로 안됨', '인계사항)', '양쪽 슬개골 탈구 , 왼쪽 십자인대 수술예정인 아이인데 신체검사상 drawer 는 약간 있는데 관절 부종소견은 없어서 보호자분께 관절낭절개시 확인후 필요시 진행한다고 말씀드렸어요. 고관절 체크 다시한번 해주시고 아이 내원하면 정원장님 호출해주세요, 같이 보신데요. 고관절은 신체검사상에서는 불안정성 있는데 특별한 통증호소는 없었어요. 정원장님하고 다시한번 체크해주시고 다른 소견있으면 보호자분에 안내드려야할것 같아요(DJD는 설명 안드렸고 탈구 위험성만 말씀드렸어요ㅠ)'], 'assessment': [], 'plan': []}
# {'date': '2023-03-13 19:05', 'subjective': ['Subjective', 'CC: 원무과확인용', '피드백,차트열람 완료', '3/13 차트(좌측 후지파행) 및 검사자료 전송완료'], 'assessment': [], 'plan': []}
# 확정진단
# 1786
# 슬개골 (아) 탈구- (좌측-2,3,4기)
# 슬개골 (아) 탈구- (좌측-2,3,4기) 박주미
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 56
#      54         print(page.page_content)
#      55 if assessment_data:
# ---> 56     assessment_table = make_assessment_table(assessment_data)
#      57     subjective_one['assessment'].append(assessment_table)
#      64 #print(subjective_one)
#      65
#      66
#      67 #Plan 위치 정보 추출
#
# Cell In[86], line 129, in make_assessment_table(pages)
#     126         if points[0][0] > max_point and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
#     127             assessment['Sign'].append(page.page_content)
# --> 129 assessment_df = pd.DataFrame(assessment)
#     130 return assessment_df
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/Library/Caches/pypoetry/virtualenvs/Capstone/lib/python3.11/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# ## Vital Check 데이터 추출

# %%
def extract_vital_check(pages):
    extracted_pages = []

    vital_page_num = 0
    vital_y_point = 0

    lab_page_num = 0
    lab_y_point = 0

    for page in pages:
        metadata = page.metadata
        coordinates = metadata['coordinates']

        x_point = coordinates['points'][0][0]
        y_height = coordinates['points'][1][1] - coordinates['points'][0][1]


        if page.page_content.lower() == '날짜' and x_point == 30.35:
            vital_y_point = coordinates['points'][0][1]
            vital_page_num = metadata['page_number']
            
        
        if page.page_content.lower() == 'lab' and x_point == 33.35 and y_height > 20:
            lab_y_point = coordinates['points'][0][1]
            lab_page_num = metadata['page_number']

    if vital_page_num and vital_y_point and lab_page_num and lab_y_point:
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']
            page_number = metadata['page_number']

            if vital_page_num == lab_page_num:
                if page_number == vital_page_num and points[0][1] > vital_y_point and points[0][1] < lab_y_point:
                    extracted_pages.append(page)
            elif vital_page_num < lab_page_num:
                if page_number == vital_page_num and points[0][1] > vital_y_point:
                    extracted_pages.append(page)
                elif page_number == lab_page_num and points[0][1] < lab_y_point:
                    extracted_pages.append(page)
                elif page_number > vital_page_num and page_number < lab_page_num:
                    extracted_pages.append(page)
    
    return extracted_pages


def make_vital_check_table(pages):
    vital_check = {
        '날짜' : [],
        '시간' : [],
        'BW(Kg)' : [],
        'BT(C)' : [],
        'BP(mmHg)' : [],
        'HR(/min)' : [],
        'Sign' : [],
    }
    data_list = []

    for page in pages:
        data_list.append(page.page_content)
    
    for i in range(0, len(data_list), 7):
        vital_check['날짜'].append(data_list[i])
        vital_check['시간'].append(data_list[i+1])
        vital_check['BW(Kg)'].append(data_list[i+2])
        vital_check['BT(C)'].append(data_list[i+3])
        vital_check['BP(mmHg)'].append(data_list[i+4])
        vital_check['HR(/min)'].append(data_list[i+5])
        vital_check['Sign'].append(data_list[i+6])
    
    vital_check_df = pd.DataFrame(vital_check)

    return vital_check_df

# %% [markdown]
# ## Vital Check Main

# %%
import numpy as np
from langchain_community.document_loaders import UnstructuredPDFLoader
import re

pdf_filepath = '/Users/sinequanon/Desktop/PerfectS/data/pdf_data/TEST_12.pdf'

loader = UnstructuredPDFLoader(pdf_filepath, mode='elements')
pages = loader.load()

vital_check_data = extract_vital_check(pages)

vital_check_table = make_vital_check_table(vital_check_data)
print(vital_check_table)
# Out:
#             날짜     시간 BW(Kg) BT(C) BP(mmHg) HR(/min) Sign
# 0   2023-09-16  12:52   3.15  36.5        0        0  정유정
# 1   2023-09-17  14:59      0  38.2      100       90  이창백
# 2   2023-09-18  15:03   3.11  38.5      180      102  정유정
# 3   2023-09-20  15:36      0  36.5      180      180  정유정
# 4   2023-09-22  14:48   3.13  39.7      160       90  이창백
# 5   2023-09-23  16:01   3.03     0        0        0  이송인
# 6   2023-09-26  15:30   2.95  39.2      120      138  이홍주
# 7   2023-09-27  15:02   3.01    39      160      114  이홍주
# 8   2023-09-28  15:24   2.96  38.4      190       90  양준우
# 9   2023-09-29  15:27   2.95  38.6      130      108  김지후
# 10  2023-10-02  10:56   2.77     0        0        0  정유정
# 11  2023-10-03  14:59    2.7     0        0        0  김지후
# 12  2023-10-05  15:11   2.76     0        0        0  남유리
# 13  2023-10-06  15:23   2.77     0        0        0  장아람
# 14  2023-10-09  10:32   2.89  38.7        0        0  양준우

# %% [markdown]
# ## Lab 데이터만 추출

# %%
"""
전체 PDF 데이터에서
Lab 데이터만 추출
"""

def extract_lab_data_all(pages):
    extracted_pages = []

    lab_page_num = 0
    lab_y_point = 0

    for page in pages:
        metadata = page.metadata
        coordinates = metadata['coordinates']

        x_point = coordinates['points'][0][0]
        y_height = coordinates['points'][1][1] - coordinates['points'][0][1]
        
        if page.page_content.lower() == 'lab' and x_point == 33.35 and y_height > 20:
            lab_y_point = coordinates['points'][0][1]
            lab_page_num = metadata['page_number']
    
    if lab_page_num and lab_y_point:
        metadata = page.metadata
        points = metadata['coordinates']['points']
        page_number = metadata['page_number']
        
        for page in pages:
            if page_number == lab_page_num and points[0][1] > lab_y_point:
                extracted_pages.append(page)
            elif page_number > lab_page_num:
                extracted_pages.append(page)
    
    return extracted_pages

# %% [markdown]
# ## Lab 데이터 테이블 별 데이터 추출하기

# %%
import pandas as pd

"""
전체 PDF 데이터 중에서
Lab 테이블 날짜 위치 추출
"""
def extract_lab_table_date(pages):
    date_pattern = re.compile(r"\d{4}-\d{2}-\d{2}")

    date = []
    date_points = []
    date_pages = []

    for page in pages:
        metadata = page.metadata
        coordinates = metadata['coordinates']
        points = metadata['coordinates']['points']

        matches = date_pattern.findall(page.page_content)
        x_point = points[0][0]
        y_height = points[1][1] - points[0][1]

        if matches and x_point == 36.02 and y_height >10:
            date.append(page.page_content)
            date_points.append(coordinates['points'][0][1])
            date_pages.append(metadata['page_number'])
    
    result = np.column_stack((date, date_points, date_pages))
    
    return result


"""
Lab 데이터 전체와 간격의 정보를 입력해서
Lab 테이블 날짜 별로 데이터 추출하기
"""
def extract_lab_data_via_interval_info(pages, interval_info):
    extracted_pages = []

    start_y_point = float(interval_info[0][0])
    end_y_point = float(interval_info[1][0])
    start_page = int(interval_info[0][1])
    end_page = int(interval_info[1][1])

    if end_page == 0:
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if metadata['page_number'] == start_page and points[0][1] > start_y_point:
                extracted_pages.append(page)
            elif metadata['page_number'] > start_page:
                extracted_pages.append(page)
    else:
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            #같은 페이지인 경우
            if start_page == end_page:
                if metadata['page_number'] == start_page and points[0][1] > start_y_point and points[1][1] < end_y_point:
                    extracted_pages.append(page)
            # 다른 페이지인 경우
            else:
                if metadata['page_number'] > start_page and metadata['page_number'] < end_page:
                    extracted_pages.append(page)
                if metadata['page_number'] == start_page and points[0][1] > start_y_point:
                    extracted_pages.append(page)
                if metadata['page_number'] == end_page and points[1][1] < end_y_point:
                    extracted_pages.append(page)

    return extracted_pages


def extract_lab_data(pages):
    extracted_pages = []
    
    y_point = 0
    page_num = 0

    for page in pages:
        metadata = page.metadata
        points = metadata['coordinates']['points']

        if page.page_content == '검사명' and points[0][0] == 30.35:
            y_point = points[1][1]
            page_num = metadata['page_number']
    
    for page in pages:
        metadata = page.metadata
        points = metadata['coordinates']['points']

        if metadata['page_number'] == page_num and points[0][1] > y_point:
            extracted_pages.append(page)
        elif metadata['page_number'] > page_num:
            extracted_pages.append(page)
    
    return extracted_pages


"""
표 데이터를 입력받으면
테이블 반환
"""
def make_lab_table(pages):
    lab = {
        "검사명" : [],
        "결과값" : [],
        "단위" : [],
        "status" : [],
        "MIN" : [],
        "MAX" : [],
        "Description" : []
    }

    y_points = []
    page_info = []

    for page in pages:
        if page.metadata['coordinates']['points'][0][0] == 30.35:
            y_points.append(page.metadata['coordinates']['points'][0][1])
            page_info.append(page.metadata['page_number'])
            lab['검사명'].append(page.page_content)


    for point, page_ in zip(y_points, page_info):
        
        # 결과값 단위 나누기
        # 255.46
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            # 결과값 데이터 찾고
            if points[0][0] > 240 and points[0][0] < 342 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                result = page.page_content
                # 단위 데이터가 존재한다면
                if points[3][0] > 278:
                    split_result = result.split(' ', 1)
                    if len(split_result) == 2:
                        text, unit = split_result
                    else:
                        text = split_result[0]
                        unit = None
                    lab['결과값'].append(text)
                    lab['단위'].append(unit)
                else:
                    lab['결과값'].append(result)
                    lab['단위'].append(None)
        
        # 기호 추출 ()
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] == 342.16 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                lab['status'].append(page.page_content)
                not_present = False
        if not_present:
            lab['status'].append(None)
        
        # Min 추출
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > 380 and points[2][0] < 460 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                lab['MIN'].append(page.page_content)
                not_present = False
        if not_present:
            lab['MIN'].append(None)

        # Max 추출
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']
            if points[0][0] > 450 and points[2][0] < 485 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                lab['MAX'].append(page.page_content)
                not_present = False
        if not_present:
            lab['MAX'].append(None)

        # Description 추출
        not_present = True
        for page in pages:
            metadata = page.metadata
            points = metadata['coordinates']['points']

            if points[0][0] > 500 and points[0][1] > (point - 4) and points[0][1] < (point + 4) and metadata['page_number'] == page_:
                lab['Description'].append(page.page_content)
                not_present = False
        if not_present:
            lab['Description'].append(None)

    lab_df = pd.DataFrame(lab)
    return lab_df

    # print("결과값 :",lab['결과값'])
    # print("단위 :",lab['단위'])
    # print("status :",lab['status'])
    # print("Min :", lab['MIN'])
    # print("Max :", lab['MAX'])
    # print("결과값 길이 :",len(lab['결과값']))
    # print("단위 길이 :", len(lab['단위']))
    # print("status 길이 :",len(lab['status']))
    # print("Min 길이 :", len(lab['MIN']))
    # print("Max 길이 :", len(lab['MAX']))
    # print("Des 길이 : ", len(lab['Description']))

# %%
import numpy as np
from langchain_community.document_loaders import UnstructuredPDFLoader
import re

pdf_filepath = '/Users/sinequanon/Desktop/PerfectS/data/pdf_data/TEST_12.pdf'

loader = UnstructuredPDFLoader(pdf_filepath, mode='elements')
pages = loader.load()

lab_pages = extract_lab_data_all(pages)

lab_pages_date = extract_lab_table_date(lab_pages)

lab_date = np.append(lab_pages_date, [[0,0,0]], axis=0)


for i in range(len(lab_date)-1):
    y_point = []
    page_num = []

    print(lab_date)
    y_point.append(lab_date[i][1])
    page_num.append(lab_date[i][2])
    y_point.append(lab_date[i+1][1])
    page_num.append(lab_date[i+1][2])

    interval_info = np.column_stack((y_point, page_num))
    
    extracted_pages = extract_lab_data_via_interval_info(lab_pages, interval_info)
    #print(len(extracted_pages))

    # Lab 한 테이블 데이터 모두 추출
    extracted_pages = extract_lab_data(extracted_pages)
    break
    
    lab_table = make_lab_table(extracted_pages)
    lab_table.to_csv(f"lab{i}.csv", index=True)
# Out:
# [['2023-09-16' '115.80000000000007' '49']
#  ['2023-09-16' '645.88' '49']
#  ['2023-09-16' '266.03999999999996' '50']
#  ['2023-09-16' '44.940000000000055' '51']
#  ['2023-09-17' '149.82000000000005' '51']
#  ['2023-09-17' '662.89' '51']
#  ['2023-09-17' '44.940000000000055' '52']
#  ['2023-09-20' '183.83000000000004' '52']
#  ['2023-09-20' '305.72' '52']
#  ['2023-09-23' '410.61' '52']
#  ['2023-09-23' '163.99' '53']
#  ['2023-09-24' '302.89' '53']
#  ['2023-09-25' '407.77000000000004' '53']
#  ['2023-09-28' '512.6500000000001' '53']
#  ['2023-09-29' '617.53' '53']
#  ['0' '0' '0']]

# %% [markdown]
# # Deep Document Understanding
# - 표, 그림, 사진, 글 다 구분 영역

# %%
import nltk
nltk.download('wordnet')

22$
# Out:
#   Cell In[93], line 4
#     22$
#       ^
# SyntaxError: invalid syntax

# %%
# !python3 t_recognizer.py --inputs=/home/pjw/Capstone/data/test_1.pdf --threshold=0.2 --mode=layout --output_dir=/home/pjw/Capstone/data/tables
